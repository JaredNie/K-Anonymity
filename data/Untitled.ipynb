# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv",header = None,names=['a','b','c','d','e','f','g'] )

# %%
df.loc[3:4,4]=df['e'].str.replace('White','')

# %%
df
# Out:
#     a                  b           c                    d       e        f  \
# 0  39          State-gov   Bachelors        Never-married   White     Male
# 1  50   Self-emp-not-inc   Bachelors   Married-civ-spouse   White     Male
# 2  38            Private     HS-grad             Divorced   White     Male
# 3  53            Private        11th   Married-civ-spouse   Black     Male
# 4  28            Private   Bachelors   Married-civ-spouse   Black   Female
#
#                 g       4
# 0   United-States     NaN
# 1   United-States     NaN
# 2   United-States     NaN
# 3   United-States   Black
# 4            Cuba   Black

# %%
df.loc[df['a']<40]
# Out:
#     a           b           c                    d       e        f  \
# 0  39   State-gov   Bachelors        Never-married   White     Male
# 2  38     Private     HS-grad             Divorced   White     Male
# 4  28     Private   Bachelors   Married-civ-spouse   Black   Female
#
#                 g       4
# 0   United-States     NaN
# 2   United-States     NaN
# 4            Cuba   Black

# %%
df.loc

# %%
df.isnull()
dd=df.dropna(axis='index',how='all',inplace = False)

# %%
dd
# Out:
#     a                  b           c                    d       e        f  \
# 0  39          State-gov   Bachelors        Never-married   White     Male
# 1  50   Self-emp-not-inc   Bachelors   Married-civ-spouse   White     Male
# 2  38            Private     HS-grad             Divorced   White     Male
# 3  53            Private        11th   Married-civ-spouse   Black     Male
# 4  28            Private   Bachelors   Married-civ-spouse   Black   Female
#
#                 g       4
# 0   United-States     NaN
# 1   United-States     NaN
# 2   United-States     NaN
# 3   United-States   Black
# 4            Cuba   Black

# %%
dd['b'].str.replace('Private','bss')
dd
# Out:
#     a                  b           c                    d       e        f  \
# 0  39          State-gov   Bachelors        Never-married   White     Male
# 1  50   Self-emp-not-inc   Bachelors   Married-civ-spouse   White     Male
# 2  38            Private     HS-grad             Divorced   White     Male
# 3  53            Private        11th   Married-civ-spouse   Black     Male
# 4  28            Private   Bachelors   Married-civ-spouse   Black   Female
#
#                 g       4
# 0   United-States     NaN
# 1   United-States     NaN
# 2   United-States     NaN
# 3   United-States   Black
# 4            Cuba   Black

# %%
dd.loc[:,'a'].str.replace("","sss")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-7caf498f20c7> in <module>
# ----> 1 dd.loc[:,'a'].str.replace("","sss")
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5061         if (name in self._internal_names_set or name in self._metadata or
#    5062                 name in self._accessors):
# -> 5063             return object.__getattribute__(self, name)
#    5064         else:
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     169             # we're accessing the attribute of the class, i.e., Dataset.geo
#     170             return self._accessor
# --> 171         accessor_obj = self._accessor(obj)
#     172         # Replace the property with the accessor object. Inspired by:
# ...

# %%
dd['f'].str.isnumeric()

# %%
dd
# Out:
#     a                  b           c                    d       e        f  \
# 0  39          State-gov   Bachelors        Never-married   White     Male
# 1  50   Self-emp-not-inc   Bachelors   Married-civ-spouse   White     Male
# 2  38            Private     HS-grad             Divorced   White     Male
# 3  53            Private        11th   Married-civ-spouse   Black     Male
# 4  28            Private   Bachelors   Married-civ-spouse   Black   Female
#
#                 g       4
# 0   United-States     NaN
# 1   United-States     NaN
# 2   United-States     NaN
# 3   United-States   Black
# 4            Cuba   Black

# %%
dd.mean(axis=0)
# Out:
# a    41.6
# dtype: float64

# %%
# Out:
#     a                  b           c                    d       e        f  \
# 0  39          State-gov   Bachelors        Never-married   White     Male
# 1  50   Self-emp-not-inc   Bachelors   Married-civ-spouse   White     Male
# 2  38            Private     HS-grad             Divorced   White     Male
# 3  53            Private        11th   Married-civ-spouse   Black     Male
# 4  28            Private   Bachelors   Married-civ-spouse   Black   Female
#
#         4
# 0     NaN
# 1     NaN
# 2     NaN
# 3   Black
# 4   Black

# %%
dd.set_index("a",inplace=True,drop=False)

# %%
dd
# Out:
#      a                  b           c                    d       e        f
# a
# 39  39          State-gov   Bachelors        Never-married   White     Male
# 50  50   Self-emp-not-inc   Bachelors   Married-civ-spouse   White     Male
# 38  38            Private     HS-grad             Divorced   White     Male
# 53  53            Private        11th   Married-civ-spouse   Black     Male
# 28  28            Private   Bachelors   Married-civ-spouse   Black   Female

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
dd.loc
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: '39'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-5692dee15759> in <module>
# ----> 1 dd.loc['39']
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1498
# ...
